# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- ------------
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.4.0
# appdirs                               1.4.4
# argcomplete                           1.12.3
# argon2-cffi                           21.1.0
# arrow                                 1.2.1
# asn1crypto                            1.4.0
# async-generator                       1.10
# async-timeout                         4.0.1
# asynctest                             0.13.0
# attrs                                 21.2.0
# Babel                                 2.9.1
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.6
# binaryornot                           0.4.4
# black                                 21.12b0
# ...

# %%
import pandas as pd

# %%
# %pip install XGboost
# Out:
# ...
#      |████████████████████████████████| 173.5 MB 9.4 kB/s
# ...
